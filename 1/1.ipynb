# %%
with open("input.txt") as d:

    data = d.read().splitlines()



nr_is_zero = 0
current_nr = 50
max_nr = 100

for i in data:
    d = i[0]
    steps = int(i[1:])
    
    if d == "L":
        new_nr = current_nr - steps
    else:
        new_nr = current_nr + steps

    new_nr = new_nr % max_nr

    if new_nr == 0:
        nr_is_zero += 1

    current_nr = new_nr

print(nr_is_zero)
# Out:
# 3

# %%
nr_is_zero = 0
current_nr = 50
max_nr = 100

for i in data:
    d = i[0]
    steps = int(i[1:])
    
    if d == "L":
        new_nr = current_nr - steps
    else:
        new_nr = current_nr + steps

    if new_nr <= 0:
        nr_is_zero += 1 + (abs(new_nr) // max_nr)
    elif new_nr > max_nr:
        nr_is_zero += (abs(new_nr) // max_nr)
    elif new_nr == max_nr:
        nr_is_zero += 1

    print(steps, new_nr, nr_is_zero)

    new_nr = new_nr % max_nr

    print(new_nr)

    current_nr = new_nr

print(nr_is_zero)
# Out:
# 68 -18 1
# 82
# 30 52 1
# 52
# 48 100 2
# 0
# 5 -5 3
# 95
# 60 155 4
# 55
# 55 0 5
# 0
# 1 -1 6
# 99
# 99 0 7
# 0
# 14 14 7
# 14
# 82 -68 8
# 32
# 8

# %%
abs(-60) // max_nr
# Out:
# 0
